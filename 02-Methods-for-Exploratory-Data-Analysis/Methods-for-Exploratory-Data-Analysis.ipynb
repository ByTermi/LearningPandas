# %%
import pandas as pd

# %%
df = pd.read_csv('../survey_results_public.csv')
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df.shape
# Out:
# (64461, 61)

# %% [markdown]
# ### View all columns in a data set
# #### Set Option method
#
# As observed in the above output, it does not show all the columns. The default (20 columns) behavior shows a truncated view of the columns and rows. Often we want to get a glance at all the columns and their data. To achieve this, we can use the pd.set_option() method with its option — display.max_columns.

# %%
pd.set_option('display.max_columns', 61)

df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %% [markdown]
# ### Quick view of the first and the last few rows
# #### Head and tail methods
#
# The head() method returns the first five while the tail() function returns the last five rows of the data set by default. If you like to see more or fewer rows, you can specify any number between brackets ().

# %%
df.head(3)
# Out:
#    Respondent                      MainBranch Hobbyist  Age Age1stCode  \
# 0           1  I am a developer by profession      Yes  NaN         13
# 1           2  I am a developer by profession       No  NaN         19
# 2           3     I code primarily as a hobby      Yes  NaN         15
#
#   CompFreq  CompTotal  ConvertedComp             Country    CurrencyDesc  \
# 0  Monthly        NaN            NaN             Germany   European Euro
# 1      NaN        NaN            NaN      United Kingdom  Pound sterling
# 2      NaN        NaN            NaN  Russian Federation             NaN
#
#   CurrencySymbol DatabaseDesireNextYear  \
# 0            EUR   Microsoft SQL Server
# 1            GBP                    NaN
# 2            NaN                    NaN
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 1                                        NaN
# 2                                        NaN
#
# ...

# %%
df.tail(3)
# Out:
#        Respondent MainBranch Hobbyist  Age Age1stCode CompFreq  CompTotal  \
# 64458       64898        NaN      Yes  NaN        NaN      NaN        NaN
# 64459       64925        NaN      Yes  NaN        NaN      NaN        NaN
# 64460       65112        NaN      Yes  NaN        NaN      NaN        NaN
#
#        ConvertedComp   Country CurrencyDesc CurrencySymbol  \
# 64458            NaN  Viet Nam          NaN            NaN
# 64459            NaN    Poland          NaN            NaN
# 64460            NaN     Spain          NaN            NaN
#
#                                 DatabaseDesireNextYear  \
# 64458                                              NaN
# 64459  DynamoDB;Elasticsearch;MongoDB;MySQL;PostgreSQL
# 64460                     MariaDB;Microsoft SQL Server
#
#                               DatabaseWorkedWith DevType  \
# 64458                                        NaN     NaN
# 64459                                     Oracle     NaN
# ...

# %% [markdown]
# shape() is a data frame attribute that returns the size of the data set with the total number of rows and the number of columns (rows, columns) in the data set.

# %%
df.shape
# Out:
# (64461, 61)

# %% [markdown]
# ### Info method
#
# The info() method shows a concise summary of the data frame as the name indicates. It returns the data frame Index, the total number of rows & columns, columns names, column data types, non-null values and count of different data types.
#
# Non-null values are essential to note here. They show much data is in each column is use able. Null values are not that useful, and you might want to replace them with some data or remove those rows altogether. We will review data cleaning techniques in a future article.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
# ...

# %% [markdown]
# ### Descriptive statistics summary
# #### Describe method
#
# The describe() method is used to see the summary of the descriptive statistics. It summarizes a data set and shows the output with central tendency (mean), dispersion (standard deviation), percentile (25th, 50th, 75th), count, min and max.

# %%
df.describe()
# Out:
# c:\Users\Alumno_AI\Documents\Pandas_JNB\LearningPandas\env_pandas\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: overflow encountered in square
#   sqr = _ensure_numeric((avg - values) ** 2)
#          Respondent           Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  64461.000000  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean   32554.079738     30.834111  3.190464e+242   1.037561e+05     40.782174
# std    18967.442360      9.585392            inf   2.268853e+05     17.816383
# min        1.000000      1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%    16116.000000     24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%    32231.000000     29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%    49142.000000     35.000000   1.250000e+05   9.500000e+04     44.000000
# max    65639.000000    279.000000  1.111111e+247   2.000000e+06    475.000000

# %% [markdown]
# ### Random data sampling
# #### Sample method
#
# The sample() method returns a random number of rows and columns from the data frame. By default, it returns one row, but we can input any number in the method brackets.

# %%
df.sample()
# Out:
#        Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 17935       17999  I am a developer by profession      Yes  27.0         16
#
#       CompFreq  CompTotal  ConvertedComp Country  CurrencyDesc CurrencySymbol  \
# 17935  Monthly     3500.0        12420.0    Peru  Peruvian sol            PEN
#
#       DatabaseDesireNextYear          DatabaseWorkedWith  \
# 17935                    NaN  Microsoft SQL Server;MySQL
#
#                                                  DevType  \
# 17935  Developer, back-end;Developer, front-end;Devel...
#
#                                             EdLevel          Employment  \
# 17935  Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Employed full-time
#
#                     Ethnicity Gender  \
# 17935  Hispanic or Latino/a/x    Man
#
#                                               JobFactors             JobSat  \
# 17935  Flex time or a flexible schedule;Languages, fr...  Very dissatisfied
#
# ...

# %%
df.sample(3)
# Out:
#        Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 22557       22643  I am a developer by profession      Yes  34.0         26
# 36052       36240  I am a developer by profession      Yes  31.0         11
# 40520       41124  I am a developer by profession      Yes   NaN        NaN
#
#       CompFreq  CompTotal  ConvertedComp         Country  \
# 22557   Yearly    32000.0        41363.0  United Kingdom
# 36052   Yearly   140000.0       140000.0   United States
# 40520      NaN        NaN            NaN        Pakistan
#
#                CurrencyDesc CurrencySymbol     DatabaseDesireNextYear  \
# 22557        Pound sterling            GBP           Cassandra;SQLite
# 36052  United States dollar            USD  MongoDB;PostgreSQL;SQLite
# 40520                   NaN            NaN        MySQL;Oracle;SQLite
#
#                     DatabaseWorkedWith  \
# 22557  Microsoft SQL Server;PostgreSQL
# 36052    DynamoDB;Elasticsearch;SQLite
# ...

# %% [markdown]
# ### Unique values and frequency tables
# #### Unique method
#
# The unique() method returns a unique value of a column. Null values are excluded by default.

# %%
df['Hobbyist'].unique()
# Out:
# array(['Yes', 'No', nan], dtype=object)

# %% [markdown]
# ### Value counts method
#
# value_counts() method takes things a step further. It shows unique values in a column as well as their count. The output is a concise and useful frequency table in descending order.

# %%
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    50388
# No     14028
# Name: count, dtype: int64

# %% [markdown]
# ### Correlation between columns
#
# In statistics, correlation shows the relationship between two numerical variables (columns in our case). This method helps us quickly review if any two columns have a negative or positive correlation (values are between 0 and 1).
#
# A value of one means the two variables are positively correlated, and an increase in one variable results in an increase in the other variable and vice versa. In the output below, we can see that the correlation between ConvertedComp and Age columns is positive and weak (0.107002).
#
# It excludes null values and object data types columns by default. It is an essential method while making a feature selection for the machine learning model (more on this later)

# %%
df.drop(columns=['MainBranch'])
# If you want to see the correlation between columns, all of them must contain numeric values
#df.corr()
# Out:
#        Respondent Hobbyist   Age Age1stCode CompFreq  CompTotal  \
# 0               1      Yes   NaN         13  Monthly        NaN
# 1               2       No   NaN         19      NaN        NaN
# 2               3      Yes   NaN         15      NaN        NaN
# 3               4      Yes  25.0         18      NaN        NaN
# 4               5      Yes  31.0         16      NaN        NaN
# ...           ...      ...   ...        ...      ...        ...
# 64456       64858      Yes   NaN         16      NaN        NaN
# 64457       64867      Yes   NaN        NaN      NaN        NaN
# 64458       64898      Yes   NaN        NaN      NaN        NaN
# 64459       64925      Yes   NaN        NaN      NaN        NaN
# 64460       65112      Yes   NaN        NaN      NaN        NaN
#
#        ConvertedComp             Country    CurrencyDesc CurrencySymbol  \
# 0                NaN             Germany   European Euro            EUR
# ...

# %% [markdown]
# ![Correlation image](screnshoot.png)
